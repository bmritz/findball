# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import radians, tan
# %matplotlib inline
predictions_and_actuals = pd.read_csv("/Users/brianritz/temp/pred_and_act.csv")
predictions_and_actuals = predictions_and_actuals[predictions_and_actuals.velocity > 0]
fps240 = predictions_and_actuals[(predictions_and_actuals.fd==3) & (predictions_and_actuals.fps==240)]
fps120 = predictions_and_actuals[(predictions_and_actuals.fd==3) & (predictions_and_actuals.fps==120)]

# %%
fps240
# Out:
#       Unnamed: 0  fd       velo  pitch_no  distance_ft  fps  zoom  degrees  \
# 721           41   3  52.084858        41           30  240     0       90
# 795           42   3  50.593093        42           30  240     0       90
# 851           43   3  54.833138        43           30  240     0       90
# 923           44   3  49.540609        44           30  240     0       90
# 985           45   3  51.059359        45           30  240     0       90
# 1040          46   3  55.894923        46           30  240     0       90
# 1114          47   3  52.488935        47           30  240     0       90
# 1165          48   3  54.482755        48           30  240     0       90
# 1210          49   3  50.850442        49           30  240     0       90
# 1262          50   3  56.309366        50           30  240     0       90
# 1908          73   3  55.620821        73           40  240     0       90
# ...

# %%
plt.figure()
plt.scatter(fps120.velocity, fps120.resid)

# %%
predictions_and_actuals.resid.pow(2).mean()
# Out:
# 44.036164744360491

# %%
training
# Out:
#      Unnamed: 0  photo_no  distance    x1    y1    x2    y2   predicted  \
# 0             0         0       100  1069  1223  2688  1023   98.661576
# 1             1         1       100   780  1237  2375  1222  100.491259
# 2             2         2       100   525  1241  2144  1288   98.661576
# 3             3         3       100  1301  1241  3043  1268   89.994948
# 4             4         4        95   978  1236  2668  1230   93.522051
# 5             5         5        95   791  1254  2462  1237   94.859225
# 6             6         6        95   358  1259  2077  1246   91.531746
# 7             7         7        95  1364  1270  3223  1252   82.696108
# 8             8         8        90  1079  1274  2855  1258   87.787449
# 9             9         9        90   742  1277  2507  1266   88.493469
# 10           10        10        90   343  1288  2139  1248   86.523190
# 11           11        11        90  1190  1273  3099  1253   79.814704
# ...
